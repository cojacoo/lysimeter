# %%
import numpy as np
import scipy as sp
import matplotlib.pylab as plt
import seaborn as sns
import matplotlib.gridspec as gridspec

# %%
import pandas as pd

# %% [markdown]
# ### BALANCE + TENSIOMETER

# %%
lysi=pd.read_csv('Daten/098201_CONFIG_20160112T134552.csv',na_values='OverRange')

# %%
lysi.head()
# Out:
#                  Timestamp TZ  Waage_1 (kg)  Waage_2 (kg)  Waage_3 (kg)  \
# 0  2015/12/17 13:52:00.005  n      -999.900      -999.900      -999.900
# 1  2015/12/17 13:54:00.009  n        59.141        49.616        61.908
# 2  2015/12/17 13:56:00.014  n        59.144        49.623        61.905
# 3  2015/12/17 13:58:00.000  n        59.150        49.604        61.899
# 4  2015/12/17 14:00:00.004  n        59.150        49.606        61.899
#
#    Vakuumstation (hPa)  T5_01 (hPa)  T5_02 (hPa)  T5_03 (hPa)  T5_04 (hPa)  \
# 0               -999.9    957.95328    733.34408    561.73436    22055.402
# 1               -999.9    956.84360    729.05696    562.70972          NaN
# 2               -999.9    958.87976    729.32488    564.52856          NaN
# 3               -999.9    956.49392    731.54840    566.03796          NaN
# 4               -999.9    954.36440    729.12040    564.67444          NaN
#
#       ...       T5_19 (hPa)  T5_20 (hPa)  T5_21 (hPa)  T5_22 (hPa)  \
# ...

# %%
lysi.index=pd.to_datetime(lysi['Timestamp'],format='%Y/%m/%d %H:%M:%S.%f')

# %%
lysi.iloc[1:,2:5].plot()

# %%
#lysi.iloc[1:,6:12].head()
lysi.iloc[1:,6:12].plot()
ylim(-10,100)
title('Lysimeter 1 - Tensiometer')

# %%
#lysi.iloc[1:,12:18].head()
lysi.iloc[1:,12:18].plot()
ylim(-10,180)
# Out:
# (-10, 180)

# %%
#lysi.iloc[1:,18:24].head()
lysi.iloc[1:,18:24].plot()
ylim(-10,320)
# Out:
# (-10, 320)

# %% [markdown]
# ### TDR

# %%
TDR1=pd.read_csv('2015-12/Monitor36555-EN.csv',na_values='NaN',skiprows=7,skipinitialspace=True)
TDR1=pd.concat([TDR1,pd.read_csv('2016-01/Monitor36555-EN.csv',na_values='NaN',skiprows=7,skipinitialspace=True)])
TDR1.index=pd.to_datetime(TDR1['Date']+' '+TDR1['Time'],format='%d-%m-%Y %H:%M:%S')

# %%
TDR2=pd.read_csv('2015-12/Monitor36554-EN.csv',na_values='NaN',skiprows=7,skipinitialspace=True)
TDR2=pd.concat([TDR2,pd.read_csv('2016-01/Monitor36554-EN.csv',na_values='NaN',skiprows=7,skipinitialspace=True)])
TDR2.index=pd.to_datetime(TDR2['Date']+' '+TDR2['Time'],format='%d-%m-%Y %H:%M:%S')

# %%
TDR1.iloc[:,4].plot(label='TDR1')
TDR2.iloc[:,4].plot(label='TDR2')
legend()

# %%
TDR3=pd.read_csv('2015-12/Monitor36556-EN.csv',na_values='NaN',skiprows=7,skipinitialspace=True)
TDR3=pd.concat([TDR3,pd.read_csv('2016-01/Monitor36556-EN.csv',na_values='NaN',skiprows=7,skipinitialspace=True)])
TDR3.index=pd.to_datetime(TDR3['Date']+' '+TDR3['Time'],format='%d-%m-%Y %H:%M:%S')

# %%
TDR4=pd.read_csv('2015-12/Monitor36557-EN.csv',na_values='NaN',skiprows=7,skipinitialspace=True)
TDR4=pd.concat([TDR4,pd.read_csv('2016-01/Monitor36557-EN.csv',na_values='NaN',skiprows=7,skipinitialspace=True)])
TDR4.index=pd.to_datetime(TDR4['Date']+' '+TDR4['Time'],format='%d-%m-%Y %H:%M:%S')

# %%
TDR3.iloc[:,4].plot(label='TDR3')
TDR4.iloc[:,4].plot(label='TDR4')
legend()

# %%
TDR5=pd.read_csv('2015-12/Monitor36558-EN.csv',na_values='NaN',skiprows=7,skipinitialspace=True)
TDR5=pd.concat([TDR5,pd.read_csv('2016-01/Monitor36558-EN.csv',na_values='NaN',skiprows=7,skipinitialspace=True)])
TDR5.index=pd.to_datetime(TDR5['Date']+' '+TDR5['Time'],format='%d-%m-%Y %H:%M:%S')

# %%
TDR6=pd.read_csv('2015-12/Monitor36559-EN.csv',na_values='NaN',skiprows=7,skipinitialspace=True)
TDR6=pd.concat([TDR6,pd.read_csv('2016-01/Monitor36559-EN.csv',na_values='NaN',skiprows=7,skipinitialspace=True)])
TDR6.index=pd.to_datetime(TDR6['Date']+' '+TDR6['Time'],format='%d-%m-%Y %H:%M:%S')

# %%
TDR5.iloc[:,4].plot(label='TDR5')
TDR6.iloc[:,4].plot(label='TDR6')
legend()
